# %%
# -------------------------------------------------------------
# 0. Install requirements
# -------------------------------------------------------------
import os
import yaml
# !pip install ood-metrics
print(">> Installazione requirements...")
os.system("pip install -r requirements.txt")
# Out:
# Requirement already satisfied: ood-metrics in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: matplotlib<4.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from ood-metrics) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.15 in /usr/local/lib/python3.12/dist-packages (from ood-metrics) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from ood-metrics) (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.0->ood-metrics) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.0->ood-metrics) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.0->ood-metrics) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.0->ood-metrics) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0,>=3.0->ood-metrics) (1.17.0)
# >> Installazione requirements...
# 256

# %%
REPO_URL = "https://github.com/MatteoSanna23/AnomalySegmentation.git"
REPO_DIR = "AnomalySegmentation"
DATASET_DIR = "tiny-imagenet/tiny-imagenet-200"
ZIP_PATH = "tiny-imagenet-200.zip"

# %%
import os

# -------------------------------------------------------------
# 1. Clone repo if not exist
# -------------------------------------------------------------
if not os.path.exists(REPO_DIR):
    print(">> Clonazione della repository...")
    os.system(f"git clone --branch firts_steps {REPO_URL}")  # clone the 'firts_steps' branch
else:
    print(">> Repository già presente, niente clone.")

os.chdir(REPO_DIR)
# Out:
# >> Clonazione della repository...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Estrai il file zip nella cartella locale di Colab (/content/dataset_validation)
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/Validation_Dataset.zip" -d "/content/dataset_validation"

# %%
# Verifica di essere nel posto giusto (dovresti vedere evalAnomaly.py)
# %cd eval
# !ls
# Out:
# /content/AnomalySegmentation/eval
# dataset.py		 evalAnomaly.py		    iouEval.py
# erfnet_nobn.py		 eval_cityscapes_color.py   __pycache__
# erfnet.py		 eval_cityscapes_server.py  README.md
# evalAnomaly_eomt.py	 eval_forwardTime.py	    results.txt
# evalAnomaly_original.py  eval_iou.py		    transform.py

# %%
# 1. Road Anomaly
print(">>> Esecuzione su ROAD ANOMALY...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 2. Road Anomaly (SMIYC RA-21)
print(">>> Esecuzione su SMIYC RA-21...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 3. Road Obstacle (SMIYC RO-21)
print(">>> Esecuzione su ROAD OBSTACLE...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 4. Fishyscapes Lost & Found (FS L&F)
print(">>> Esecuzione su FS L&F...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound_full/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 5. Fishyscapes Static
print(">>> Esecuzione su FS STATIC...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/fs_static/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"
# Out:
# >>> Esecuzione su ROAD ANOMALY...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adding CLS token to pos_embed (concatenation)
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Weights loaded. Missing keys: [], Unexpected keys: ['criterion.empty_weight', 'encoder.backbone.reg_token', 'encoder.backbone.blocks.0.ls1.gamma', 'encoder.backbone.blocks.0.ls2.gamma', 'encoder.backbone.blocks.1.ls1.gamma', 'encoder.backbone.blocks.1.ls2.gamma', 'encoder.backbone.blocks.2.ls1.gamma', 'encoder.backbone.blocks.2.ls2.gamma', 'encoder.backbone.blocks.3.ls1.gamma', 'encoder.backbone.blocks.3.ls2.gamma', 'encoder.backbone.blocks.4.ls1.gamma', 'encoder.backbone.blocks.4.ls2.gamma', 'encoder.backbone.blocks.5.ls1.gamma', 'encoder.backbone.blocks.5.ls2.gamma', 'encoder.backbone.blocks.6.ls1.gamma', 'encoder.backbone.blocks.6.ls2.gamma', 'encoder.backbone.blocks.7.ls1.gamma', 'encoder.backbone.blocks.7.ls2.gamma', 'encoder.backbone.blocks.8.ls1.gamma', 'encoder.backbone.blocks.8.ls2.gamma', 'encoder.backbone.blocks.9.ls1.gamma', 'encoder.backbone.blocks.9.ls2.gamma', 'encoder.backbone.blocks.10.ls1.gamma', 'encoder.backbone.blocks.10.ls2.gamma', 'encoder.backbone.blocks.11.ls1.gamma', 'encoder.backbone.blocks.11.ls2.gamma']
# 11 - 4 - 48 - 22 - 25 - 0 - 14 - 28 - 56 - 59 - 58 - 5 - 18 - 10 - 57 - 51 - 21 - 3 - 7 - 1 - 12 - 54 - 23 - 47 - 26 - 31 - 38 - 36 - 32 - 44 - 24 - 43 - 50 - 16 - 35 - 9 - 15 - 52 - 37 - 55 - 49 - 2 - 53 - 20 - 19 - 17 - 6 - 8 - 30 - 41 - 13 - 46 - 34 - 42 - 29 - 39 - 27 - 40 - 33 - 45 -
#
# [MSP] AUPRC: 9.24 | FPR@95: 96.34
# [MaxLogit] AUPRC: 8.61 | FPR@95: 96.50
# [Entropy] AUPRC: 12.50 | FPR@95: 86.84
# [RbA] AUPRC: 9.18 | FPR@95: 96.33
# >>> Esecuzione su SMIYC RA-21...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adding CLS token to pos_embed (concatenation)
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Weights loaded. Missing keys: [], Unexpected keys: ['criterion.empty_weight', 'encoder.backbone.reg_token', 'encoder.backbone.blocks.0.ls1.gamma', 'encoder.backbone.blocks.0.ls2.gamma', 'encoder.backbone.blocks.1.ls1.gamma', 'encoder.backbone.blocks.1.ls2.gamma', 'encoder.backbone.blocks.2.ls1.gamma', 'encoder.backbone.blocks.2.ls2.gamma', 'encoder.backbone.blocks.3.ls1.gamma', 'encoder.backbone.blocks.3.ls2.gamma', 'encoder.backbone.blocks.4.ls1.gamma', 'encoder.backbone.blocks.4.ls2.gamma', 'encoder.backbone.blocks.5.ls1.gamma', 'encoder.backbone.blocks.5.ls2.gamma', 'encoder.backbone.blocks.6.ls1.gamma', 'encoder.backbone.blocks.6.ls2.gamma', 'encoder.backbone.blocks.7.ls1.gamma', 'encoder.backbone.blocks.7.ls2.gamma', 'encoder.backbone.blocks.8.ls1.gamma', 'encoder.backbone.blocks.8.ls2.gamma', 'encoder.backbone.blocks.9.ls1.gamma', 'encoder.backbone.blocks.9.ls2.gamma', 'encoder.backbone.blocks.10.ls1.gamma', 'encoder.backbone.blocks.10.ls2.gamma', 'encoder.backbone.blocks.11.ls1.gamma', 'encoder.backbone.blocks.11.ls2.gamma']
# 0 - 1 - 5 - 9 - 8 - 2 - 6 - 3 - 4 - 7 -
#
# [MSP] AUPRC: 15.11 | FPR@95: 92.28
# [MaxLogit] AUPRC: 13.47 | FPR@95: 93.47
# [Entropy] AUPRC: 14.09 | FPR@95: 91.71
# [RbA] AUPRC: 15.11 | FPR@95: 92.19
# >>> Esecuzione su ROAD OBSTACLE...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adding CLS token to pos_embed (concatenation)
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Weights loaded. Missing keys: [], Unexpected keys: ['criterion.empty_weight', 'encoder.backbone.reg_token', 'encoder.backbone.blocks.0.ls1.gamma', 'encoder.backbone.blocks.0.ls2.gamma', 'encoder.backbone.blocks.1.ls1.gamma', 'encoder.backbone.blocks.1.ls2.gamma', 'encoder.backbone.blocks.2.ls1.gamma', 'encoder.backbone.blocks.2.ls2.gamma', 'encoder.backbone.blocks.3.ls1.gamma', 'encoder.backbone.blocks.3.ls2.gamma', 'encoder.backbone.blocks.4.ls1.gamma', 'encoder.backbone.blocks.4.ls2.gamma', 'encoder.backbone.blocks.5.ls1.gamma', 'encoder.backbone.blocks.5.ls2.gamma', 'encoder.backbone.blocks.6.ls1.gamma', 'encoder.backbone.blocks.6.ls2.gamma', 'encoder.backbone.blocks.7.ls1.gamma', 'encoder.backbone.blocks.7.ls2.gamma', 'encoder.backbone.blocks.8.ls1.gamma', 'encoder.backbone.blocks.8.ls2.gamma', 'encoder.backbone.blocks.9.ls1.gamma', 'encoder.backbone.blocks.9.ls2.gamma', 'encoder.backbone.blocks.10.ls1.gamma', 'encoder.backbone.blocks.10.ls2.gamma', 'encoder.backbone.blocks.11.ls1.gamma', 'encoder.backbone.blocks.11.ls2.gamma']
# 28 - 2 - 15 - 11 - 0 - 24 - 13 - 18 - 7 - 22 - 9 - 10 - 20 - 8 - 16 - 12 - 25 - 17 - 14 - 26 - 1 - 29 - 27 - 23 - 19 - 4 - 21 - 6 - 5 - 3 -
#
# [MSP] AUPRC: 0.60 | FPR@95: 99.42
# [MaxLogit] AUPRC: 3.59 | FPR@95: 98.75
# [Entropy] AUPRC: 2.14 | FPR@95: 97.84
# [RbA] AUPRC: 0.60 | FPR@95: 99.51
# >>> Esecuzione su FS L&F...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adding CLS token to pos_embed (concatenation)
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Weights loaded. Missing keys: [], Unexpected keys: ['criterion.empty_weight', 'encoder.backbone.reg_token', 'encoder.backbone.blocks.0.ls1.gamma', 'encoder.backbone.blocks.0.ls2.gamma', 'encoder.backbone.blocks.1.ls1.gamma', 'encoder.backbone.blocks.1.ls2.gamma', 'encoder.backbone.blocks.2.ls1.gamma', 'encoder.backbone.blocks.2.ls2.gamma', 'encoder.backbone.blocks.3.ls1.gamma', 'encoder.backbone.blocks.3.ls2.gamma', 'encoder.backbone.blocks.4.ls1.gamma', 'encoder.backbone.blocks.4.ls2.gamma', 'encoder.backbone.blocks.5.ls1.gamma', 'encoder.backbone.blocks.5.ls2.gamma', 'encoder.backbone.blocks.6.ls1.gamma', 'encoder.backbone.blocks.6.ls2.gamma', 'encoder.backbone.blocks.7.ls1.gamma', 'encoder.backbone.blocks.7.ls2.gamma', 'encoder.backbone.blocks.8.ls1.gamma', 'encoder.backbone.blocks.8.ls2.gamma', 'encoder.backbone.blocks.9.ls1.gamma', 'encoder.backbone.blocks.9.ls2.gamma', 'encoder.backbone.blocks.10.ls1.gamma', 'encoder.backbone.blocks.10.ls2.gamma', 'encoder.backbone.blocks.11.ls1.gamma', 'encoder.backbone.blocks.11.ls2.gamma']
# 30 - 33 - 27 - 49 - 25 - 40 - 57 - 50 - 13 - 0 - 94 - 65 - 81 - 39 - 1 - 72 - 80 - 48 - 84 - 85 - 55 - 95 - 5 - 38 - 86 - 98 - 53 - 82 - 9 - 22 - 8 - 60 - 36 - 90 - 32 - 54 - 75 - 2 - 21 - 47 - 67 - 99 - 52 - 35 - 6 - 18 - 17 - 3 - 51 - 11 - 58 - 74 - 87 - 23 - 68 - 15 - 59 - 61 - 29 - 12 - 93 - 37 - 79 - 56 - 43 - 44 - 78 - 19 - 71 - 31 - 97 - 88 - 64 - 41 - 34 - 96 - 76 - 73 - 77 - 83 - 10 - 89 - 24 - 70 - 45 - 14 - 42 - 62 - 16 - 28 - 26 - 69 - 4 - 46 - 66 - 63 - 7 - 20 - 91 - 92 -
#
# [MSP] AUPRC: 0.28 | FPR@95: 95.58
# [MaxLogit] AUPRC: 0.28 | FPR@95: 95.65
# [Entropy] AUPRC: 0.30 | FPR@95: 94.99
# [RbA] AUPRC: 0.28 | FPR@95: 95.43
# >>> Esecuzione su FS STATIC...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adding CLS token to pos_embed (concatenation)
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Weights loaded. Missing keys: [], Unexpected keys: ['criterion.empty_weight', 'encoder.backbone.reg_token', 'encoder.backbone.blocks.0.ls1.gamma', 'encoder.backbone.blocks.0.ls2.gamma', 'encoder.backbone.blocks.1.ls1.gamma', 'encoder.backbone.blocks.1.ls2.gamma', 'encoder.backbone.blocks.2.ls1.gamma', 'encoder.backbone.blocks.2.ls2.gamma', 'encoder.backbone.blocks.3.ls1.gamma', 'encoder.backbone.blocks.3.ls2.gamma', 'encoder.backbone.blocks.4.ls1.gamma', 'encoder.backbone.blocks.4.ls2.gamma', 'encoder.backbone.blocks.5.ls1.gamma', 'encoder.backbone.blocks.5.ls2.gamma', 'encoder.backbone.blocks.6.ls1.gamma', 'encoder.backbone.blocks.6.ls2.gamma', 'encoder.backbone.blocks.7.ls1.gamma', 'encoder.backbone.blocks.7.ls2.gamma', 'encoder.backbone.blocks.8.ls1.gamma', 'encoder.backbone.blocks.8.ls2.gamma', 'encoder.backbone.blocks.9.ls1.gamma', 'encoder.backbone.blocks.9.ls2.gamma', 'encoder.backbone.blocks.10.ls1.gamma', 'encoder.backbone.blocks.10.ls2.gamma', 'encoder.backbone.blocks.11.ls1.gamma', 'encoder.backbone.blocks.11.ls2.gamma']
# 11 - 4 - 22 - 25 - 0 - 14 - 28 - 5 - 18 - 10 - 21 - 3 - 7 - 1 - 12 - 23 - 26 - 24 - 16 - 9 - 15 - 2 - 20 - 19 - 17 - 6 - 8 - 13 - 29 - 27 -
#
# [MSP] AUPRC: 2.02 | FPR@95: 96.78
# [MaxLogit] AUPRC: 1.97 | FPR@95: 96.82
# [Entropy] AUPRC: 2.40 | FPR@95: 94.45
# [RbA] AUPRC: 2.02 | FPR@95: 96.73
