# %%
# -------------------------------------------------------------
# 0. Install requirements
# -------------------------------------------------------------
import os
import yaml
# !pip install ood-metrics
print(">> Installazione requirements...")
os.system("pip install -r requirements.txt")
# Out:
# ...
# >> Installazione requirements...
# 256

# %%
REPO_URL = "https://github.com/MatteoSanna23/AnomalySegmentation.git"
REPO_DIR = "AnomalySegmentation"
BRANCH_NAME = "Leo"
DATASET_DIR = "tiny-imagenet/tiny-imagenet-200"
ZIP_PATH = "tiny-imagenet-200.zip"

# %%
import os
import shutil # Importa shutil per cancellare la cartella se serve

# -------------------------------------------------------------
# 1. Clone repo if not exist
# -------------------------------------------------------------

if not os.path.exists(REPO_DIR):
    print(f">> Clonazione del branch {BRANCH_NAME}...")
    # Qui inseriamo la variabile {BRANCH_NAME} nel comando
    os.system(f"git clone --branch {BRANCH_NAME} {REPO_URL}")
else:
    print(">> Repository già presente. Se vuoi cambiare branch, cancella la cartella 'AnomalySegmentation' dai file a sinistra e riavvia.")

os.chdir(REPO_DIR)
# Out:
# >> Repository già presente. Se vuoi cambiare branch, cancella la cartella 'AnomalySegmentation' dai file a sinistra e riavvia.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Estrazione file zip nella cartella locale di Colab (/content/dataset_validation)
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/Validation_Dataset.zip" -d "/content/dataset_validation"

# %%
# Verifica di essere nel posto giusto (dovresti vedere evalAnomaly.py)
# %cd eval
# !ls
# Out:
# /content/AnomalySegmentation/eval
# dataset.py		 evalAnomaly.py		     eval_iou.py   results.txt
# erfnet_nobn.py		 evalAnomaly_temperature.py  iouEval.py    transform.py
# erfnet.py		 eval_cityscapes_color.py    outputs_eval
# evalAnomaly_eomt.py	 eval_cityscapes_server.py   __pycache__
# evalAnomaly_original.py  eval_forwardTime.py	     README.md

# %%
# 5. Fishyscapes Static
print(">>> Esecuzione su FS STATIC...")
# !python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/fs_static/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"
# Out:
# >>> Esecuzione su FS STATIC...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# model.safetensors: 100% 346M/346M [00:04<00:00, 84.9MB/s]
# Resizing pos_embed from 64x64 to 32x64
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Inizio inferenza su 30 immagini con temperature: [0.1, 0.3, 0.5, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3, 1.5, 2.0]
# Processing 0/30: 7.jpg
# Processing 10/30: 25.jpg
# Processing 20/30: 3.jpg
#
#  --- RESULTS FOR TEMPERATURE SCALING ---
#
# [MSP (T=0.1)] AUPRC: 1.72 | FPR@95: 91.43
# [MSP (T=0.3)] AUPRC: 1.72 | FPR@95: 95.21
# [MSP (T=0.5)] AUPRC: 1.72 | FPR@95: 94.77
# [MSP (T=0.7)] AUPRC: 1.72 | FPR@95: 94.23
# [MSP (T=0.8)] AUPRC: 1.72 | FPR@95: 93.99
# [MSP (T=0.9)] AUPRC: 1.72 | FPR@95: 93.79
# [MSP (T=1.0)] AUPRC: 1.72 | FPR@95: 93.62
# [MSP (T=1.1)] AUPRC: 1.72 | FPR@95: 93.49
# [MSP (T=1.2)] AUPRC: 1.72 | FPR@95: 93.38
# [MSP (T=1.3)] AUPRC: 1.72 | FPR@95: 93.32
# ...

# %%
# 1. Road Anomaly
print(">>> Esecuzione su ROAD ANOMALY...")
# !python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 2. Road Anomaly (SMIYC RA-21)
print(">>> Esecuzione su SMIYC RA-21...")
# !python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 3. Road Obstacle (SMIYC RO-21)
print(">>> Esecuzione su ROAD OBSTACLE...")
# !python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 4. Fishyscapes Lost & Found (FS L&F)
print(">>> Esecuzione su FS L&F...")
# !python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound_full/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 5. Fishyscapes Static
#print(">>> Esecuzione su FS STATIC...")
#!python evalAnomaly_temperature.py --input "/content/dataset_validation/Validation_Dataset/fs_static/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"
# Out:
# >>> Esecuzione su ROAD ANOMALY...
# Loading EoMT model weights from: /content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt
# Resizing pos_embed from 64x64 to 32x64
# Adapting attn_mask_probs from torch.Size([3]) to torch.Size([4])
# Inizio inferenza su 60 immagini con temperature: [0.1, 0.3, 0.5, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3, 1.5, 2.0]
# Processing 0/60: 38.jpg
# Processing 10/60: 11.jpg
# Processing 20/60: 10.jpg
# Processing 30/60: 5.jpg
# Processing 40/60: 8.jpg
# Processing 50/60: 18.jpg
#
#  --- RESULTS FOR TEMPERATURE SCALING ---
#
# [MSP (T=0.1)] AUPRC: 13.40 | FPR@95: 80.70
# [MSP (T=0.3)] AUPRC: 13.49 | FPR@95: 78.11
# [MSP (T=0.5)] AUPRC: 13.51 | FPR@95: 77.53
# [MSP (T=0.7)] AUPRC: 13.51 | FPR@95: 77.43
# [MSP (T=0.8)] AUPRC: 13.51 | FPR@95: 77.43
# [MSP (T=0.9)] AUPRC: 13.52 | FPR@95: 77.45
# [MSP (T=1.0)] AUPRC: 13.52 | FPR@95: 77.46
# [MSP (T=1.1)] AUPRC: 13.52 | FPR@95: 77.36
# [MSP (T=1.2)] AUPRC: 13.52 | FPR@95: 77.01
# ...

# %%
"""
# 1. Road Anomaly
print(">>> Esecuzione su ROAD ANOMALY...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 2. Road Anomaly (SMIYC RA-21)
print(">>> Esecuzione su SMIYC RA-21...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 3. Road Obstacle (SMIYC RO-21)
print(">>> Esecuzione su ROAD OBSTACLE...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 4. Fishyscapes Lost & Found (FS L&F)
print(">>> Esecuzione su FS L&F...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound_full/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"

# 5. Fishyscapes Static
print(">>> Esecuzione su FS STATIC...")
# !python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/fs_static/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"
"""
# Out:
# '\n# 1. Road Anomaly\nprint(">>> Esecuzione su ROAD ANOMALY...")\n!python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"\n\n# 2. Road Anomaly (SMIYC RA-21)\nprint(">>> Esecuzione su SMIYC RA-21...")\n!python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"\n\n# 3. Road Obstacle (SMIYC RO-21)\nprint(">>> Esecuzione su ROAD OBSTACLE...")\n!python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "/content/drive/MyDrive/Colab Notebooks/epoch_106-step_19902_eomt.ckpt"\n\n# 4. Fishyscapes Lost & Found (FS L&F)\nprint(">>> Esecuzione su FS L&F...")\n!python evalAnomaly_eomt.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound
# ...

# %%
"""
# 1. Road Anomaly
print(">>> Esecuzione su ROAD ANOMALY...")
# !python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "erfnet_pretrained.pth"

# 2. Road Anomaly (SMIYC RA-21)
print(">>> Esecuzione su SMIYC RA-21...")
# !python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "erfnet_pretrained.pth"

# 3. Road Obstacle (SMIYC RO-21)
print(">>> Esecuzione su ROAD OBSTACLE...")
# !python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "erfnet_pretrained.pth"

# 4. Fishyscapes Lost & Found (FS L&F)
print(">>> Esecuzione su FS L&F...")
# !python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound_full/images/*.png" --loadWeights "erfnet_pretrained.pth"

# 5. Fishyscapes Static
print(">>> Esecuzione su FS STATIC...")
# !python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/fs_static/images/*.jpg" --loadWeights "erfnet_pretrained.pth"
"""
# Out:
# '\n# 1. Road Anomaly\nprint(">>> Esecuzione su ROAD ANOMALY...")\n!python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly/images/*.jpg" --loadWeights "erfnet_pretrained.pth"\n\n# 2. Road Anomaly (SMIYC RA-21)\nprint(">>> Esecuzione su SMIYC RA-21...")\n!python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadAnomaly21/images/*.png" --loadWeights "erfnet_pretrained.pth"\n\n# 3. Road Obstacle (SMIYC RO-21)\nprint(">>> Esecuzione su ROAD OBSTACLE...")\n!python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/RoadObsticle21/images/*.webp" --loadWeights "erfnet_pretrained.pth"\n\n# 4. Fishyscapes Lost & Found (FS L&F)\nprint(">>> Esecuzione su FS L&F...")\n!python evalAnomaly.py --input "/content/dataset_validation/Validation_Dataset/FS_LostFound_full/images/*.png" --loadWeights "erfnet_pretrained.pth"\n\n# 5. Fishyscapes Static\nprint(">>> Esecuzione su FS STATIC...")\n!python evalAnomaly.py --input "/cont
# ...
